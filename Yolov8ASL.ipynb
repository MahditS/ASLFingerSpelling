# %%
# !nvidia-smi
# Out:
# Thu Nov 30 21:22:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8l.pt conf=0.25 data='/content/drive/MyDrive/Datasets/AmericanSignLanguageLetters.v6-raw.yolov8/data.yaml' epochs=50 imgsz=416
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo val model='/content/runs/detect/train3/weights/best.pt' data='/content/drive/MyDrive/Datasets/AmericanSignLanguageLetters.v6-raw.yolov8/data.yaml' split=test
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43626654 parameters, 0 gradients, 164.9 GFLOPs
# val: Scanning /content/drive/MyDrive/Datasets/AmericanSignLanguageLetters.v6-raw.yolov8/test/labels... 72 images, 0 backgrounds, 0 corrupt: 100% 72/72 [02:00<00:00,  1.67s/it]
# val: New cache created: /content/drive/MyDrive/Datasets/AmericanSignLanguageLetters.v6-raw.yolov8/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:04<00:00,  1.15it/s]
#                    all         72         72      0.885      0.908      0.944      0.908
#                      A         72          1       0.84          1      0.995      0.995
#                      B         72          3      0.921          1      0.995      0.955
#                      C         72          4      0.948          1      0.995      0.931
# ...
